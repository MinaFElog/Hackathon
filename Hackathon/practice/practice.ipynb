# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pandas.read_csv('two_clusters.csv')
print(data)
# Out:
#     Unnamed: 0                a         b         c         d
# 0            0       John Yoder  0.948302  0.051698  0.143269
# 1            1       Linda Diss  0.785162  0.214838  0.847444
# 2            2      Minnie Hoyt  0.653954  0.346046  0.230950
# 3            3  Jesus Doolittle  0.369016  0.630984  0.853027
# 4            4     Tracy Worley  0.364943  0.635057  0.894561
# ..         ...              ...       ...       ...       ...
# 95          95   Linda Kowalski  0.363169  0.636831  0.134492
# 96          96  Russell Rodgers  0.915297  0.084703  0.761680
# 97          97      Janice Bass  0.902089  0.097911  0.201483
# 98          98   Jane Parmenter  0.527486  0.472514  0.905930
# 99          99    Cara Santiago  0.736626  0.263374  0.961264
#
# [100 rows x 5 columns]

# %%
print(data['d'])
# Out:
# 0     0.143269
# 1     0.847444
# 2     0.230950
# 3     0.853027
# 4     0.894561
#         ...
# 95    0.134492
# 96    0.761680
# 97    0.201483
# 98    0.905930
# 99    0.961264
# Name: d, Length: 100, dtype: float64

# %%
plt.scatter(data['c'],data['d'])
plt.show()

# %%
columns = df.iloc[:, [-2, -1]]
columns
# Out:
#            c         d
# 0   0.051698  0.143269
# 1   0.214838  0.847444
# 2   0.346046  0.230950
# 3   0.630984  0.853027
# 4   0.635057  0.894561
# ..       ...       ...
# 95  0.636831  0.134492
# 96  0.084703  0.761680
# 97  0.097911  0.201483
# 98  0.472514  0.905930
# 99  0.263374  0.961264
#
# [100 rows x 2 columns]

# %%
data['avg'] = columns.mean(axis=1)
data['avg']
# Out:
# 0     0.097483
# 1     0.531141
# 2     0.288498
# 3     0.742005
# 4     0.764809
#         ...
# 95    0.385661
# 96    0.423192
# 97    0.149697
# 98    0.689222
# 99    0.612319
# Name: avg, Length: 100, dtype: float64

# %%
plt.scatter(data['avg'], data['d'])
plt.show()

# %%
data
# Out:
#     Unnamed: 0                a         b         c         d       avg
# 0            0       John Yoder  0.948302  0.051698  0.143269  0.097483
# 1            1       Linda Diss  0.785162  0.214838  0.847444  0.531141
# 2            2      Minnie Hoyt  0.653954  0.346046  0.230950  0.288498
# 3            3  Jesus Doolittle  0.369016  0.630984  0.853027  0.742005
# 4            4     Tracy Worley  0.364943  0.635057  0.894561  0.764809
# ..         ...              ...       ...       ...       ...       ...
# 95          95   Linda Kowalski  0.363169  0.636831  0.134492  0.385661
# 96          96  Russell Rodgers  0.915297  0.084703  0.761680  0.423192
# 97          97      Janice Bass  0.902089  0.097911  0.201483  0.149697
# 98          98   Jane Parmenter  0.527486  0.472514  0.905930  0.689222
# 99          99    Cara Santiago  0.736626  0.263374  0.961264  0.612319
#
# [100 rows x 6 columns]

# %%
data.to_csv('new_two_clusters.csv')
