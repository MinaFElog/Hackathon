# %%
# Import the libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.impute import SimpleImputer

# %%
# Import the dataset
dataset = pd.read_csv('wine.csv')
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# Define independant and dependant variables
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
# Taking care of missing data
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(X)
X = imputer.transform(X)

# %%
# Split dataset into train and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=1)

# %%
# Train classification model
classifier = RandomForestClassifier(n_estimators = 40)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=40)

# %%
# Predicting the test set
y_pred = classifier.predict(X_test)

# %%
# Evaluating the model
accuracy = accuracy_score(y_test, y_pred)
print('The accuracy of the test set is:', accuracy)

CVS = cross_val_score(classifier, X_test, y_test, cv=5).mean()
print('The cross validation score is:', CVS)
# Out:
# The accuracy of the test set is: 0.8375
# The cross validation score is: 0.703125

# %%
# Creating confusion matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[128  26]
#  [ 26 140]]

# %%
print(pd.DataFrame(y_test))
# Out:
#         0
# 0     bad
# 1    good
# 2    good
# 3    good
# 4    good
# ..    ...
# 315   bad
# 316   bad
# 317   bad
# 318  good
# 319  good
#
# [320 rows x 1 columns]

# %%
sample_y = classifier.predict([X_test[-1]])
print(sample_y)
# Out:
# ['good']
