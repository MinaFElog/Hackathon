# %%
age = 18

# %%
if(age > 18 and age < 30):
    print('The age is over 18 and under 30')
else:
    print('The age is 18, under 18 or over 30')
# Out:
# The age is 18, under 18 or over 30

# %%
if(age >= 18 and age <= 30):
    print('The age is between 18 to 30')
# Out:
# The age is between 18 to 30

# %%
if(18 <= age <= 30):
    print('The age is between 18 to 30')
# Out:
# The age is between 18 to 30

# %%
if(age > 18 or age < 30):
    print('The age is over 18 or under 30')
else:
    print('The age is 18, under 18 or above 30')
# Out:
# The age is over 18 or under 30

# %%
if(not age > 18):
    print('The age is 18 or under 18')
else:
    print('The age is over 18')
# Out:
# The age is 18 or under 18
