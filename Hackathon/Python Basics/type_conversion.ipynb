# %%
num = '12'

# %%
print(type(num))
# Out:
# <class 'str'>

# %%
print(num)
# Out:
# 12

# %%
new_num = int(num)
print(new_num)
# Out:
# 12

# %%
num = 0
print(bool(num))
# Out:
# False

# %%
num = 4
print(bool(num))
# Out:
# True

# %%
age = 30
print('She is', age, 'years old.')
# Out:
# She is 30 years old.

# %%
age = 30
print('She is '+ str(age)+ ' years old.')
# Out:
# She is 30 years old.

# %%
num = 12
print(float(num))
# Out:
# 12.0

# %%
num = '12'
print(float(num))
# Out:
# 12.0
